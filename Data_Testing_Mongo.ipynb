# %%
# Instaling PyMongo, this is the interface to connect to MongoDB with Python
! python -m pip install pymongo==3.9

# %%
import datetime                            # Imports datetime library

import pymongo
from pymongo import MongoClient

# uri (uniform resource identifier) defines the connection parameters 
uri = "mongodb+srv://admin:admin@cluster0.fs6sz.mongodb.net/prueba?retryWrites=true&w=majority"
# start client to connect to MongoDB server 
client = MongoClient( uri )
db = client.prueba

# %%
import random
def test_data_MongoDB(device_id, starting_date):
    '''
    This function was primaraly created to create synthetic data output to the 
    MongoDB server, it the first stages of the work we did not have conclusive
    results from the NILM disagregation algortihms, so we develop this function 
    to test the application faster.
    collection_name: Name of the collection. (I don't know how to actually do this) 
    device_id: Device_Id (It can be either 'nevera', 'washing_machine' or 'microondas')
    starting_date: First Date of measurements (USe 'YYYY-MM-DD')
    Does not return anything, values already save into the MongoDB Atlas server.
    '''
    if device_id == 'nevera':
        first_datetime =  datetime.datetime.fromisoformat(starting_date)
        last_datetime = datetime.datetime.utcnow().replace(hour = 0, minute = 0, second=0, microsecond=0)
        current_datetime = first_datetime
        while last_datetime > current_datetime:
            for i in range (12):  
                for i in range(6):
                    data = { "power": random.randint(89, 91),}
                    deviceId = device_id
                    minute = current_datetime
                    db.house_2.update_one( # here you can select a different collection: Just change house_2 part.
                    {'deviceId': deviceId, 'd': minute},
                    {
                        '$push': {'samples': data},
                        '$inc': {'nsamples': 1}
                    },
                    upsert=True
                    )
                for i in range(2):
                    data = { "power": random.randint(238, 242),}
                    deviceId = device_id
                    minute = current_datetime
                    db.house_2.update_one(
                    {'deviceId': deviceId, 'd': minute},
                    {
                        '$push': {'samples': data},
                        '$inc': {'nsamples': 1}
                    },
                    upsert=True)
            current_datetime = current_datetime + datetime.timedelta(days=1)
    elif  device_id == 'washing_machine':
        first_datetime =  datetime.datetime.fromisoformat(starting_date)
        last_datetime = datetime.datetime.utcnow().replace(hour = 0, minute = 0, second=0, microsecond=0)
        current_datetime = first_datetime
        while last_datetime > current_datetime:
            for i in range(80):
                data = { "power": random.randint(0, 2),}
                deviceId = device_id
                minute = current_datetime
                db.house_2.update_one(
                {'deviceId': deviceId, 'd': minute},
                {
                    '$push': {'samples': data},
                    '$inc': {'nsamples': 1}
                },
                upsert=True
                )
            for i in range(5):
                data = { "power": random.randint(450, 470),}
                deviceId = device_id
                minute = current_datetime
                db.house_2.update_one(
                {'deviceId': deviceId, 'd': minute},
                {
                    '$push': {'samples': data},
                    '$inc': {'nsamples': 1}
                },
                upsert=True)
            for i in range(11):
                data = { "power": random.randint(0, 2),}
                deviceId = device_id
                minute = current_datetime
                db.house_2.update_one(
                {'deviceId': deviceId, 'd': minute},
                {
                    '$push': {'samples': data},
                    '$inc': {'nsamples': 1}
                },
                upsert=True)
            current_datetime = current_datetime + datetime.timedelta(days=1) 
    elif  device_id == 'microondas':
        first_datetime =  datetime.datetime.fromisoformat(starting_date)
        last_datetime = datetime.datetime.utcnow().replace(hour = 0, minute = 0, second=0, microsecond=0)
        current_datetime = first_datetime
        while last_datetime > current_datetime:
            for i in range(24):
                data = {
                "power": 0,
                }
                deviceId = device_id
                minute = current_datetime
                    
                db.house_1.update_one(
                {'deviceId': deviceId, 'd': minute},
                {
                    '$push': {'samples': data},
                    '$inc': {'nsamples': 1}
                },
                upsert=True
                )
                
            for i in range(3):
                data = {
                "power": random.randint(200, 400),
                }
                deviceId = device_id
                minute = current_datetime
                    
                db.house_1.update_one(
                {'deviceId': deviceId, 'd': minute},
                {
                    '$push': {'samples': data},
                    '$inc': {'nsamples': 1}
                },
                upsert=True
                )
                
            for i in range(30):
                data = {
                "power": 0,
                }
                deviceId = device_id
                minute = current_datetime
                    
                db.house_1.update_one(
                {'deviceId': deviceId, 'd': minute},
                {
                    '$push': {'samples': data},
                    '$inc': {'nsamples': 1}
                },
                upsert=True
                )

            for i in range(2):
                data = {
                "power": random.randint(200, 400),
                }
                deviceId = device_id
                minute = current_datetime
                    
                db.house_1.update_one(
                {'deviceId': deviceId, 'd': minute},
                {
                    '$push': {'samples': data},
                    '$inc': {'nsamples': 1}
                },
                upsert=True
                )

            for i in range(24):
                data = {
                "power": 0,
                }
                deviceId = device_id
                minute = current_datetime
                    
                db.house_1.update_one(
                {'deviceId': deviceId, 'd': minute},
                {
                    '$push': {'samples': data},
                    '$inc': {'nsamples': 1}
                },
                upsert=True
                )

            for i in range(2):
                data = {
                "power": random.randint(200, 400),
                }
                deviceId = device_id
                minute = current_datetime
                    
                db.house_1.update_one(
                {'deviceId': deviceId, 'd': minute},
                {
                    '$push': {'samples': data},
                    '$inc': {'nsamples': 1}
                },
                upsert=True
                )

            for i in range(11):
                data = {
                "power": 0,
                }
                deviceId = device_id
                minute = current_datetime
                    
                db.house_1.update_one(
                {'deviceId': deviceId, 'd': minute},
                {
                    '$push': {'samples': data},
                    '$inc': {'nsamples': 1}
                },
                upsert=True
                )
            current_datetime = current_datetime + datetime.timedelta(days=1)

# %%
# Give you data about fridge, from january 1 2022.
test_data_MongoDB('nevera', '2022-01-01')
